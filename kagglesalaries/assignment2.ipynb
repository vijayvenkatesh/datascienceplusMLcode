# %%
import pandas as pd
data = pd.read_csv("data/train.csv")
data = data.ix[:100]
data.tail()
# Out:
#            Id                                              Title  \
# 96   34858923    Chef De Partie Norfolk Live In up to ****  Tips
# 97   35152761                   Plastic Extrusion Setter  Nights
# 98   35272754  Assistant Manager  Suffolk Coastal Restaurant ...
# 99   35450486                            Cluster Revenue Manager
# 100  35584733                        Restaurant Manager  Suffolk
#
#                                        FullDescription  \
# 96   Chef De Partie Norfolk Live In up to **** Tips...
# 97   There is now a vacancy for a Plastic Extrusion...
# 98   Assistant Manager  Suffolk Coastal Restaurant ...
# 99   Our client is part of an international hotel c...
# 100  Restaurant Manager  Suffolk A great position f...
#
#                      LocationRaw LocationNormalized ContractType ContractTime  \
# 96          Norfolk, UK, Norfolk            Norfolk          NaN          NaN
# 97   Haywards Heath, West Sussex     Haywards Heath          NaN    permanent
# ...

# %%
#data['TitleNormal']=data.Title.map(lambda x: 'chef' if 'chef' in x.lower() else x)
#data.TitleNormal['developer' in data.TitleNormal] = 'software'
data['TitleNormal'] = 'software' if data[data['TitleNormal'].str.contains("Software|SOFTWARE|software")] 
#data[data['TitleNormal'].str.contains("Sales|SALES|sales")] = 'sales' # Yaay - they added this as Github 620
#data['TitleNormal'].apply(lambda    #df['Date'] = df['Date'].apply(lambda x: int(str(x)[-4:]))
# Out:
#   File "<ipython-input-58-13d83dbc2ed1>", line 3
#     data['TitleNormal'] = 'software' if data[data['TitleNormal'].str.contains("Software|SOFTWARE|software")]
#                                                                                                              ^
# SyntaxError: invalid syntax

# %%
# Try to categorize Title, Location, Company, 
# Create models with Title, Location, contract type
data.tail(50)
# Out:
#            Id                                              Title  \
# 51   30192171                                      Web Developer
# 52   30292879            Software Engineer/Mathematical Modeller
# 53   30502258                              Mathematical Modeller
# 54   30502270                                   Quality Engineer
# 55   30502285  Software Engineer / Algorithm Design / Mathema...
# 56   30502291                                  Software Engineer
# 57   31301427  Senior Mechanical Engineer Design and Substant...
# 58   31301430  Senior Mechanical Engineer Design and Substant...
# 59   31340140                          User Experience Developer
# 60   31347600                                      Web Developer
# 61   31559355  Field Sales Executive / Business Development  ...
# 62   31559362                                       IT Telesales
# 63   31559397  FIELD SALES ENGINEER / SALES ACCOUNT MANAGER  ...
# ...

# %%
import statsmodels.formula.api as sm
#model = sm.ols("SalaryNormalized ~ LocationNormalized", data).fit() - Gives R2 of 0.578

# %%
model.summary()
# Model as salary against Location gives a Rsquared of 0.578 - not bad but needs to improve
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       SalaryNormalized   R-squared:                       0.578
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     1.817
# Date:                Thu, 09 Jan 2014   Prob (F-statistic):             0.0175
# Time:                        21:28:16   Log-Likelihood:                -1066.2
# No. Observations:                 101   AIC:                             2220.
# Df Residuals:                      57   BIC:                             2335.
# Df Model:                          43
# ...
#                                                 coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------------------
# ...
