# %%
import pandas as pd
data = pd.read_csv("train.csv")
data = data.ix[:100]
data.tail()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 100
# Data columns (total 12 columns):
# Id                    101  non-null values
# Title                 101  non-null values
# FullDescription       101  non-null values
# LocationRaw           101  non-null values
# LocationNormalized    101  non-null values
# ContractType          1  non-null values
# ContractTime          69  non-null values
# Company               99  non-null values
# Category              101  non-null values
# SalaryRaw             101  non-null values
# SalaryNormalized      101  non-null values
# SourceName            101  non-null values
# dtypes: int64(2), object(10)

# %%
import statsmodels.formula.api as sm
model = sm.ols("SalaryNormalized ~ LocationNormalized", data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       SalaryNormalized   R-squared:                       0.578
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     1.817
# Date:                Thu, 09 Jan 2014   Prob (F-statistic):             0.0175
# Time:                        21:28:16   Log-Likelihood:                -1066.2
# No. Observations:                 101   AIC:                             2220.
# Df Residuals:                      57   BIC:                             2335.
# Df Model:                          43
# ...
#                                                 coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------------------
# ...
